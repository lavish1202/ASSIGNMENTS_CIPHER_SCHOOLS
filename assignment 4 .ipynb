# %% [markdown]
#  <b> <p style="color:red;font-size:50px; font-family:jokerman">INTRODUCTION</p></b>

# %% [markdown]
#  An individual’s annual income results from various factors. Intuitively, it is influenced by the individual’s education level, age, gender, occupation, and etc.

# %% [markdown]
#  THIS DATA SET HAS 15 COLOUMNS

# %% [markdown]
#  6 continuous, 8 nominal attributes.
# Attribute Information/Fearures/Columns
#
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * income: >50K, <=50K

# %% [markdown]
# <b><p style="color:GREEN; font-size:20px;font-family:elephant" >OBJECTIVE </p></b>
# <h>TO CREATE A  EXPLORATORY DATA ANALYSIS  (EDA) ON THE GIVEN DATA SET TO SUMMMARIZE THEIR MAIN CHARCACTERSTICS WITH VISUAL METHODS.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

missing_val = ['n/a', '-', '?']
df = pd.read_csv('adult.csv',na_values = missing_val)
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
#  <b><h1 style="color:red;font-size:15px;">OBSERVATION</h1></b>
# <b>imported the required library and read file from the downloads folder and displaying the top 5 data with the syntax df.head()</b>

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
#  <b><h1 style="color:red;font-size:15px;">OBSERVATION</h1></b>
#  <b> displaying the nows of rows and coloumns with the synatax df.shape

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
#  <b><h1 style="color:red;font-size:15px;">OBSERVATION</h1></b>
#  <b> displaying the brief statistical analaysis of the data with the syntax df.describe()

# %%
df.isnull().sum().sum()
# Out:
# 6465

# %%
df=df.dropna(how='any')

# %%
df.shape
# Out:
# (45222, 15)

# %%
del df['fnlwgt']

# %% [markdown]
# <b><h1 style="color:red;font-size:15px;">OBSERVATION</h1></b>
# <b>
#    coloumn with name fnlwgt has been dropped with the keyword del </b>

# %%
# missing values in rows earlier 6465 
a=6465
#total no of rows earlier
b=48842
c= a/b*100
print("percentage of rows lost is",c,'%')
# Out:
# percentage of rows lost is 13.236558699479955 %

# %% [markdown]
# <b><h1 style="color:red;font-size:15px;">OBSERVATION</h1></b>
# <b>
#   approximately 13 percent of rows were removed after handling the missing values </b>

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:30px; font-family:elephant;">UNIVARIATE ANALYSIS</h1></b>

# %%
sns.boxplot(y='age',data=df)

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <b>
#  - AVERAGE AGE IS AROUND 35 YEARS
#  - OUTLIERS IS 80-90 OF AGE </B>

# %%
sns.boxplot(y='educational-num',data=df)

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <B>
# - AVERAGE EDUCATIONAL NUM IS AROUND 10
# - OUTLIERS ARE BELOW 3

# %%
sns.distplot(df['capital-gain'], kde=False, rug=True)

# %%
sns.distplot(df['capital-loss'], kde=False, rug=True)

# %%
sns.boxplot(y='hours-per-week',data=df)

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <B>
#  - AVERAGE IS 40 HOURS PER WEEK
#  - 60-100 HOURS AND AND 0-30 HOURS LIES IN OUTLIER RANGE

# %%
sns.countplot(y='education', data=df)

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <B>
# - MOST OF THE ADULTS ARE FEOM HS-GRAD
# - VERY FEW BELONGS 5TH AND 6TH
# - APPROX 1% OF THE STUDENTS BELONGS TO 1-4 TH CLASS

# %%
sns.countplot(y='marital-status', data=df, palette='Greens_d')

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <B>
#  - MOST OF THE ADULTS ARE MARRIED-CIV-SPOUSE
#  - THERE ARE 15000 ADULTS WHO NEVER MARRIED
#  - APPROX 7500 ADULTS ARE DIVORCED
#  - RATIO OF WIDOWED AND SEPERATED ARE SAME
#  - NO SUCH ADULTS ARE MARRIED-AF-SPOUSE

# %%
sns.countplot(y='workclass', data=df, palette='Greens_d')

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <b>
#  - approx 34000 adults are working in private sector
#  - the ratio of self-emoloyee-inc and state-gov adults employee are nearly same
#  - 5000 adults are working under local government
#  - approx 6000 adults are self employee-not-inc
#     </b>

# %%
sns.countplot(y='income', data=df, palette='Greens_d')

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <b>
#  - around 36000 adults gets income less than 50k
#  - around 12000 adults gets income more than 50k
#     </b>

# %%
sns.countplot(y='gender', data=df, palette='Greens_d')

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <b>
#  - AROUND 33000 ADULTS BELONGS TO MALE CATEGORY
#  - AROUND 17000 ADULTS BELONGS TO FEMALE CATEGORY </b>

# %%
sns.countplot(y='race', data=df, palette='Greens_d')

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
# <b>
#  - AROUND 41000 ADULTS ARE WHITES
#  - AROUND 6000 ADULTS ARE BALCK
#  - AROUND 2000 ADULTS ARE ASIAN-PAC-ISLANDER AND REST ARE THE AMER-INDIAN-ESKIMO

# %%
sns.countplot(y='race', data=df, palette='Greens_d')

# %% [markdown]
# <b><h1 style="color:dark green ;font-size:15px; font-family:elephant;">OBSERVATION</h1></b>
#  <b>
#  - AROUND 20000 ADULTS HAVE RELATIONSHIP AS HUSBANDS
#  - AROUND 7500 ADULTS HAVE THEIR OWN CHILD
#  - AROUND 13000 ADULTS ARE NOT IN FAMILY
#  - AROUND 5000 ADULTS ARE UNMARRIED
#  - AROUND 2500 ADULTS HAVE RELATIONSHIP AS WIFE
#  - AROUND 1500 ADULTS HAVE OTHER RELATIVE </B>

# %% [markdown]
# <b><h1 style="color:blue ;font-size:30px; font-family:jokerman;">BIVARIATE ANALYSIS </h1></b>

# %%
sns.boxplot(data = df, x='income', y='age')

# %% [markdown]
# <b><h1 style="color:RED;font-size:15px; font-family:ARIAL;">OBSERVATION </h1></b>
# <B>
#  - AVERAGE 35 YERAS OF ADULTS EARN INCOME LESS THAN 50 K AND OUTLIERS ARE 80-90
#  - AVERAGE 45 YEARS OF ADULTS EARN INCOME MORE THAN 50 K AND OUTLIERS ARE 75-90

# %%
sns.boxplot(data = df, x='gender', y='age')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - AVERAGE 38 YEARS OF ADULTS ARE MALE AND 80-90 ARE THE OUTLIERS
#  - AVERAGE 35 YEARS OG ADULTS ARE FEMALE AND OUTLIERS ARE 75-90
#     </B>

# %%
sns.boxplot(data = df, x='gender', y='hours-per-week')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - GENDERS WORKS AT AN AVERAGE OF 40 HOURS PER WEEK AND REST ALL ARE OUTLIERS
#  - FEMALE WORKS AT AN AVERAGE OF 30 HOURS PER WEEK AND REST ALL ARE OUTLIERS

# %%
sns.boxplot(data = df, x='age', y='marital-status')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <b>
#  - AVERAGE AGE OF 25 YEARS NEVER MARRIED AND OUTLIERS ARE 50 TO 90
#  - AVEAGE AGE OF 45 YERAS ARE MARIIED-CIC-SPOUSE AND OUTLIERS ARE 75 TO 90
#  - AVERAGE AGE OF APPROX 60 ARE WIDOWED AND OUTLIERS ARE 20-30 AND 90
#  - AVERAGE AGE OF APPROX 40 ARE SEPERATED AND THE OUTLIERS ARE 65 TO 90
#  - AVERAGE AGE OF APPROX 45 ARE DIVORCED AND THE OUTLIERS ARE 78 TO 90
#  - AVERAGE AGE OF 40 ARE MARRIED-SPOUSE-ABSENT AND THE OUTLIERS ARE 78 TO 90
#  - AVERAGE AGE OF 30 ARE MARRIED-AF-SPOUSE ANR THE OUTLIERS ARE 40 TO 60
#     </B>

# %%
sns.boxplot(data = df, x='age', y='relationship')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - AVERAGE AGE OF APPROX 25 HAVE OWN CHILD AND OUTLIERS ARE 40 TO 90
#  - AVERAGE AGE OF APPROX 45 HAVE RELATIONSHIP AS HUSBAND AND THE OUTLIERS ARE 70 TO 90
#  - AVERAGE AGE OF APPROX 35 ARE NOT IN FAMILY AND OUTLIERS ARE 70 TO 90
#  - AVERAGE AGE OF APPROX 40  ARE UNMARRIED  AND OUTLIERS ARE 70 TO 90
#  - AVERAGE AGE OF APPROX 30 HAVE OTHER RELATIVE  AND OUTLIERS ARE 70 TO 90

# %%
sns.jointplot(x='age', y='capital-loss', data=df, kind='hex', color='k')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - THIS GRAPH SHOWS THE RELATIONSHIP BETWEEN CAPITAL LOSS AND AGE IN HEXBIN PLOTS

# %%
sns.boxplot(data = df, x='income', y='hours-per-week',hue='income')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - AN AVERAGE OF 40 HOURS PER WEEK EARNS INCOME LESS THAN 50 K AND REST ALL ARE OUTLIERS
#  - AN AVERAGE OF 50 HOURS-PER-WEEK EARNS INCOME MORE THAN 50 K AND 70 TO 100 ARE THE OUTLIERS AND 0 TO 20 ARE OUTLIERS

# %%
sns.barplot(data = df, x='gender', y='age',hue='income')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - AVERAGE OF 35 YEARS OF MALE EARNS INCOME LESS THAN 50 K AND ABOVE 40 YEARS OF MALE EARNS INCOME MORE THAN 50K
#  -  AVERAGE OF APPROX 35 YEARS OF FEMALE EARNS INCOME LESS THAN 50 K AND APPROX 40 YEARS OF FEMALE EARNS INCOME MORE THAN 50K

# %%
sns.barplot(data = df, x='gender', y='hours-per-week',hue='income')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - AVERAGE OF 40 HOURS PER WEEK MALE ADULTS EARNS INCOME LESS THAN 50K
#  - ABOVE 40 HOURS PER WEEK MALE EARNS INCOME EARNS INCOME MORE THAN 50K
#  - AVERAGE 35 HOURS PER WEEK FEMALE EARNS INCOME LESS THAN 50K
#  - ABOVE 35 HOURS PER WEEK FEMALE EARNS INCOME MORE THAN 50K

# %%
sns.boxplot(data = df, x='income', y='educational-num',hue='income')

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
#  - ADULTS WITH  AVERAGE EDUCATIONAL NUMBER 10 EARNS INCOME LESS THAN 50 K AND REST ARE OUTLIERS
#  - ADULTS WITH AVERAGE EDUCATIONAL NUMBER 11 EARNS INCOME MORE THAN 50 K AND OUTLIERS ARE 2-5 AND 13-16

# %%
sns.pairplot(df)

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
# THIS PLOT  SHOWS THE RELATIONSHIP AMONG ALL THE NUMERICALS COLUMNS IN DATA SET AND ALL THE DIAGONALS PLOT SHOWING HISTOGRAM AND REST ARE THE SCATTERS PLOTS

# %% [markdown]
# <b><h1 style="color:RED ;font-size:30px; font-family:jokerman;">CONCLUSIONS</h1></b>

# %% [markdown]
# <B>
#  - THERE ARE 6465 MISSING VALUES IN THE DATASET
#  - AFTER REOVING THE MISSING VALUES NO OF ROWS ARE 45222
#  - MALE ADULTS ARE MORE COMPARED TO FEMALE ADULTS
#  - MOSTLY PEOPLE EARN 50K AS INCOME
#  - MAINLY EDUCATION NUMBER 10 IS THE AVERAGE DATA ENTRY
#  - WHITE PEOPLE ARE HIGHEST IN RANGE
#  - AVERAGE HOURS PER WEEK OF MOST PEOPLE ARE 40 HOURS PER WEEK
#  - HUSBAND RANGE IS MORE THAN WIFE IN RELATIONSHIP STATUS
#  - MOSTLY THE NATIVE COUNTRY IS UNITED STATES

# %% [markdown]
# <b><h1 style="color:BLUE ;font-size:60px; font-family:ELEPHANT;">THANK            YOU   !</h1></b>

# %% [markdown]
# <b><h1 style="color:RED ;font-size:40px; font-family:ARIAL;">SELF EXPLORATORY PROBLEMS </h1></b>

# %%
from sklearn import preprocessing

x = df['age'].values.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_age = min_max_scaler.fit_transform(x)
df['age'] = x_age

x = df['educational-num'].values.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_education = min_max_scaler.fit_transform(x)
df['educational-num'] = x_education

x = df['capital-gain'].values.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_gain = min_max_scaler.fit_transform(x)
df['capital-gain'] = x_gain

x = df['capital-loss'].values.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_loss = min_max_scaler.fit_transform(x)
df['capital-loss'] = x_loss

x = df['hours-per-week'].values.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_hours = min_max_scaler.fit_transform(x)
df['hours-per-week'] = x_hours

# %%
df.describe()
# Out:
#                 age  educational-num  capital-gain  capital-loss  \
# count  45222.000000     45222.000000  45222.000000  45222.000000
# mean       0.295177         0.607897      0.011014      0.020339
# std        0.181067         0.170192      0.075065      0.092965
# min        0.000000         0.000000      0.000000      0.000000
# 25%        0.150685         0.533333      0.000000      0.000000
# 50%        0.273973         0.600000      0.000000      0.000000
# 75%        0.410959         0.800000      0.000000      0.000000
# max        1.000000         1.000000      1.000000      1.000000
#
#        hours-per-week
# count    45222.000000
# mean         0.407531
# std          0.122526
# min          0.000000
# 25%          0.397959
# 50%          0.397959
# 75%          0.448980
# max          1.000000

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <b>
#     DATA HAS BEEN NORMALIZED

# %%
df.head()
# Out:
#         age  workclass     education  educational-num      marital-status  \
# 0  0.109589    Private          11th         0.400000       Never-married
# 1  0.287671    Private       HS-grad         0.533333  Married-civ-spouse
# 2  0.150685  Local-gov    Assoc-acdm         0.733333  Married-civ-spouse
# 3  0.369863    Private  Some-college         0.600000  Married-civ-spouse
# 5  0.232877    Private          10th         0.333333       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male      0.000000           0.0
# 1    Farming-fishing        Husband  White   Male      0.000000           0.0
# 2    Protective-serv        Husband  White   Male      0.000000           0.0
# 3  Machine-op-inspct        Husband  Black   Male      0.076881           0.0
# 5      Other-service  Not-in-family  White   Male      0.000000           0.0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
# VALUES ARE BETWEEN 0 AND 1 NOW

# %%
pd.get_dummies(df , columns = ['workclass' , 'education' , 'marital-status' ,'relationship' ,'occupation', 'race' ,'gender','native-country' , 'income'] ,drop_first =True)
# Out:
#             age  educational-num  capital-gain  capital-loss  hours-per-week  \
# 0      0.109589         0.400000      0.000000           0.0        0.397959
# 1      0.287671         0.533333      0.000000           0.0        0.500000
# 2      0.150685         0.733333      0.000000           0.0        0.397959
# 3      0.369863         0.600000      0.076881           0.0        0.397959
# 5      0.232877         0.333333      0.000000           0.0        0.295918
# ...         ...              ...           ...           ...             ...
# 48837  0.136986         0.733333      0.000000           0.0        0.377551
# 48838  0.315068         0.533333      0.000000           0.0        0.397959
# 48839  0.561644         0.533333      0.000000           0.0        0.397959
# 48840  0.068493         0.533333      0.000000           0.0        0.193878
# 48841  0.479452         0.533333      0.150242           0.0        0.397959
#
# ...

# %% [markdown]
# <b><h1 style="color:RED ;font-size:15px; font-family:ARIAL;">OBSERVATION</h1></b>
# <B>
# ALL CATEGORICAL HAS BEEN CONVERTED TO NUMERICAL COLUMNS AS 0 AND 1
